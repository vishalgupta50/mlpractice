# %%
import pandas as pd

# %%
df1 = pd.read_csv('dummy_data.csv')

# %%
df1
# Out:
#    key1  key2   value1   value2
# 0   one     a        1        2
# 1   one     b        3        4
# 2   one     c        5        6
# 3   one     d        7        8
# 4   one     e        9       10
# 5   one     f       11       12
# 6   one     g       13       14
# 7   one     h       15       16
# 8   two     a       17       18
# 9   two     b       19       20
# 10  two     c       21       22
# 11  two     d       23       24
# 12  two     e       25       26
# 13  two     f       27       28
# 14  two     g       29       30
# 15  two     h       31       32

# %%
df2 = pd.read_csv('dummy_data.csv', index_col='key1')
df2
# Out:
#       key2   value1   value2
# key1
# one      a        1        2
# one      b        3        4
# one      c        5        6
# one      d        7        8
# one      e        9       10
# one      f       11       12
# one      g       13       14
# one      h       15       16
# two      a       17       18
# two      b       19       20
# two      c       21       22
# two      d       23       24
# two      e       25       26
# two      f       27       28
# two      g       29       30
# two      h       31       32

# %%
df3 = pd.read_csv('dummy_data.csv', index_col=['key1', 'key2'])
df3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-cf677c481c66> in <module>
# ----> 1 df3 = pd.read_csv('dummy_data.csv', index_col=['key1', 'key2'])
#       2 df3
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df4 = pd.read_csv('dummy_data1.csv')
df4
# Out:
#                                                    # hey
# a                                   b   c   d    meesage
# #hello buddy how are u              NaN NaN NaN      NaN
# # liking my code of pandas practice NaN NaN NaN      NaN
# 1                                   2   3   4      hello
# 5                                   6   7   8      world
# 9                                   10  11  12       foo

# %%
df5 = pd.read_csv('dummy_data1.csv', skiprows=[0,2,3])
df5
# Out:
#    a   b   c   d meesage
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df6 = pd.read_csv('dummy_data2.csv')
df6
# Out:
#   pandas  a   b   c     d message
# 0    one  1   2   3   4.0     NaN
# 1    two  5   6   7   NaN   world
# 2  three  9  10  11  12.0     foo

# %%
df_header = pd.read_csv('dummy_data2.csv', header=None)
df_header
# Out:
#         0  1   2   3    4        5
# 0  pandas  a   b   c    d  message
# 1     one  1   2   3    4      NaN
# 2     two  5   6   7  NaN    world
# 3   three  9  10  11   12      foo

# %%
pd.isnull(df6)
# Out:
#    pandas      a      b      c      d  message
# 0   False  False  False  False  False     True
# 1   False  False  False  False   True    False
# 2   False  False  False  False  False    False

# %%
df7 = pd.read_csv('dummy_data2.csv', na_values=['one', 'three'])
df7
# Out:
#   pandas  a   b   c     d message
# 0    NaN  1   2   3   4.0     NaN
# 1    two  5   6   7   NaN   world
# 2    NaN  9  10  11  12.0     foo

# %%
df8 = pd.read_table('dummy_data.txt')
df8
# Out:
#    key1, key2, value1, value2
# 0                one, a, 1, 2
# 1                one, b, 3, 4
# 2                one, c, 5, 6
# 3                one, d, 7, 8
# 4               one, e, 9, 10
# 5              one, f, 11, 12
# 6              one, g, 13, 14
# 7              one, h, 15, 16
# 8              two, a, 17, 18
# 9              two, b, 19, 20
# 10             two, c, 21, 22
# 11             two, d, 23, 24
# 12             two, e, 25, 26
# 13             two, f, 27, 28
# 14             two, g, 29, 30
# 15             two, h, 31, 32

# %%
pwd
# Out:
# 'C:\\Users\\VGupta\\OneDrive - Sonicwall Inc\\CANVAS\\Github\\Practice\\Pandas'

# %%
df9 = pd.read_excel('dummy_data3.xlsx', sheet_name='Sheet1', header=None)
df9
# Out:
#          0      1      2     3
# 0        a      b      c     d
# 1        1      2      3     4
# 2     good    bad   good   bad
# 3        1  False   True  True
# 4  message  hello  world  good

# %%
url = "https://www.basketball-reference.com/leagues/NBA_2015_per_game.html"
bb_data = pd.read_html(url)
bb_data
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784
#  1      2    Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609
#  2      3    Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502
#  3      4     Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579
#  4      5   Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  32.0  5.9  12.7  ...  .655
#  671  490  Thaddeus Young  PF  26  MIN  48  48  33.4  6.0  13.4  ...  .682
#  672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  .606
#  673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  .774
#  674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  .823
#
#       ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
type(bb_data)
# Out:
# list

# %%
len(bb_data)
# Out:
# 1

# %%
bb_data[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784
# 1      2    Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609
# 2      3    Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502
# 3      4     Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579
# 4      5   Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  32.0  5.9  12.7  ...  .655
# 671  490  Thaddeus Young  PF  26  MIN  48  48  33.4  6.0  13.4  ...  .682
# 672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  .606
# 673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  .774
# 674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  .823
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
bb_data[0].head(5)
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784  1.2
# 1  2   Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609  0.3
# 2  3   Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502  2.8
# 3  4    Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579  1.4
# 4  5  Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843  0.3
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  3.3  4.4  1.0  0.4  0.3  0.9  2.2   5.9
# 1  0.6  0.9  0.5  0.5  0.2  0.5  0.8   3.1
# 2  4.6  7.5  0.9  0.5  1.2  1.4  3.2   7.7
# 3  3.2  4.5  0.9  0.2  0.5  0.5  1.8   3.5
# 4  2.8  3.2  1.7  0.5  0.1  1.5  2.1  13.3
#
# [5 rows x 30 columns]

# %%
bb_data[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
bb_df = bb_data[0]

# %%
bb_df.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
bb_df[['Rk', 'Player']].head()
# Out:
#   Rk         Player
# 0  1     Quincy Acy
# 1  2   Jordan Adams
# 2  3   Steven Adams
# 3  4    Jeff Adrien
# 4  5  Arron Afflalo

# %%
bb_df['DRB']
# Out:
# 0      3.3
# 1      0.6
# 2      4.6
# 3      3.2
# 4      2.8
#       ...
# 670    3.7
# 671    3.5
# 672    4.1
# 673    4.3
# 674    3.9
# Name: DRB, Length: 675, dtype: object

# %%
type(bb_df['DRB'])
# Out:
# pandas.core.series.Series
