# %%
import pandas as pd

# %%
df = pd.read_csv('dummy_data.csv', chunksize=5)
df

# %%
df1 = pd.read_csv('dummy_data.csv', nrows=5)
df1
# Out:
#   key1  key2  value1  value2
# 0  one     a       1       2
# 1  one     b       3       4
# 2  one     c       5       6
# 3  one     d       7       8
# 4  one     e       9      10

# %%
df3 = df1[['value1', 'value2']]
df3
# Out:
#    value1  value2
# 0       1       2
# 1       3       4
# 2       5       6
# 3       7       8
# 4       9      10

# %%
df4 = df3.to_csv('df4.csv')

# %%
pwd
# Out:
# 'C:\\Users\\VGupta\\OneDrive - Sonicwall Inc\\mlpractice\\Practice\\Pandas\\pandas2'

# %%
df5 = df3.to_csv('df5.csv', sep='#', index=None)

# %%
list1 = [['a', 'b', 'c'], ['1', '2', '3']]
value = ['x', 'y', 'z']
dictionary = {k: v for k, v in zip(value, list1)}
dictionary
# Out:
# {'x': ['a', 'b', 'c'], 'y': ['1', '2', '3']}

# %%
value = """
{"name": "vishal",
 "occupation": ["Data Scientist", "Entrepreneur", "BusinessMan"],
 "Companies": {
     "company1": "Brosys.co",
     "company2": "HardSteel.co",
     "company3": "SoftCore.in"
 },
 "partners": [
     {"name": "kunal_gupta", "age": "36", "designation": ["CEO", "CTO"]},
     {"name": "Khushboo_gupta", "age": "35", "designation": "HR Head"},
     {"name": "vishal_gupta", "age": "26", "designation": "Head of Various Depts"},
     {"name": "Paritosh_kumar", "age": "35", "designation": "COO"}
 ]
}
"""

# %%
import json
dictionary_data = json.loads(value)
dictionary_data
# Out:
# {'name': 'vishal',
#  'occupation': ['Data Scientist', 'Entrepreneur', 'BusinessMan'],
#  'Companies': {'company1': 'Brosys.co',
#   'company2': 'HardSteel.co',
#   'company3': 'SoftCore.in'},
#  'partners': [{'name': 'kunal_gupta',
#    'age': '36',
#    'designation': ['CEO', 'CTO']},
#   {'name': 'Khushboo_gupta', 'age': '35', 'designation': 'HR Head'},
#   {'name': 'vishal_gupta',
#    'age': '26',
#    'designation': 'Head of Various Depts'},
#   {'name': 'Paritosh_kumar', 'age': '35', 'designation': 'COO'}]}

# %%
type(dictionary_data)
# Out:
# dict

# %%
string_format = json.dumps(dictionary_data)
string_format
# Out:
# '{"name": "vishal", "occupation": ["Data Scientist", "Entrepreneur", "BusinessMan"], "Companies": {"company1": "Brosys.co", "company2": "HardSteel.co", "company3": "SoftCore.in"}, "partners": [{"name": "kunal_gupta", "age": "36", "designation": "CEO"}, {"name": "Khushboo_gupta", "age": "35", "designation": "HR Head"}, {"name": "vishal_gupta", "age": "26", "designation": "CTO"}, {"name": "Paritosh_kumar", "age": "35", "designation": "COO"}]}'

# %%
type(string_format)
# Out:
# str

# %%
pd.DataFrame(dictionary_data['partners'])
# Out:
#              name age            designation
# 0     kunal_gupta  36             [CEO, CTO]
# 1  Khushboo_gupta  35                HR Head
# 2    vishal_gupta  26  Head of Various Depts
# 3  Paritosh_kumar  35                    COO

# %%
import requests

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
data = requests.get(url)

# %%
type(data)
# Out:
# requests.models.Response

# %%
data.status_code
# Out:
# 200

# %%
data.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38118',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38118/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38118/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38118/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38118',
#   'id': 752398252,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI4NzMwMTU2',
#   'number': 38118,
#   'title': 'Update datetimes.py',
#   'user': {'login': 'boringow',
#    'id': 62092582,
#    'node_id': 'MDQ6VXNlcjYyMDkyNTgy',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/62092582?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/boringow',
#    'html_url': 'https://github.com/boringow',
#    'followers_url': 'https://api.github.com/users/boringow/followers',
# ...
