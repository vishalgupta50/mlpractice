# %%
import pandas as pd

# %%
df = pd.read_csv('dummy_data.csv', chunksize=5)
df

# %%
df1 = pd.read_csv('dummy_data.csv', nrows=5)
df1
# Out:
#   key1  key2  value1  value2
# 0  one     a       1       2
# 1  one     b       3       4
# 2  one     c       5       6
# 3  one     d       7       8
# 4  one     e       9      10

# %%
df3 = df1[['value1', 'value2']]
df3
# Out:
#    value1  value2
# 0       1       2
# 1       3       4
# 2       5       6
# 3       7       8
# 4       9      10

# %%
df4 = df3.to_csv('df4.csv')

# %%
pwd
# Out:
# 'C:\\Users\\VGupta\\OneDrive - Sonicwall Inc\\mlpractice\\Practice\\Pandas\\pandas2'

# %%
df5 = df3.to_csv('df5.csv', sep='#', index=None)

# %%
list1 = [['a', 'b', 'c'], ['1', '2', '3']]
value = ['x', 'y', 'z']
dictionary = {k: v for k, v in zip(value, list1)}
dictionary
# Out:
# {'x': ['a', 'b', 'c'], 'y': ['1', '2', '3']}

# %%
value = """
{"name": "vishal",
 "occupation": ["Data Scientist", "Entrepreneur", "BusinessMan"],
 "Companies": {
     "company1": "Brosys.co",
     "company2": "HardSteel.co",
     "company3": "SoftCore.in"
 },
 "partners": [
     {"name": "kunal_gupta", "age": "36", "designation": ["CEO", "CTO"]},
     {"name": "Khushboo_gupta", "age": "35", "designation": "HR Head"},
     {"name": "vishal_gupta", "age": "26", "designation": "Head of Various Depts"},
     {"name": "Paritosh_kumar", "age": "35", "designation": "COO"}
 ]
}
"""

# %%
import json
dictionary_data = json.loads(value)
dictionary_data
# Out:
# {'name': 'vishal',
#  'occupation': ['Data Scientist', 'Entrepreneur', 'BusinessMan'],
#  'Companies': {'company1': 'Brosys.co',
#   'company2': 'HardSteel.co',
#   'company3': 'SoftCore.in'},
#  'partners': [{'name': 'kunal_gupta',
#    'age': '36',
#    'designation': ['CEO', 'CTO']},
#   {'name': 'Khushboo_gupta', 'age': '35', 'designation': 'HR Head'},
#   {'name': 'vishal_gupta',
#    'age': '26',
#    'designation': 'Head of Various Depts'},
#   {'name': 'Paritosh_kumar', 'age': '35', 'designation': 'COO'}]}

# %%
type(dictionary_data)
# Out:
# dict

# %%
string_format = json.dumps(dictionary_data)
string_format
# Out:
# '{"name": "vishal", "occupation": ["Data Scientist", "Entrepreneur", "BusinessMan"], "Companies": {"company1": "Brosys.co", "company2": "HardSteel.co", "company3": "SoftCore.in"}, "partners": [{"name": "kunal_gupta", "age": "36", "designation": ["CEO", "CTO"]}, {"name": "Khushboo_gupta", "age": "35", "designation": "HR Head"}, {"name": "vishal_gupta", "age": "26", "designation": "Head of Various Depts"}, {"name": "Paritosh_kumar", "age": "35", "designation": "COO"}]}'

# %%
type(string_format)
# Out:
# str

# %%
pd.DataFrame(dictionary_data['partners'])
# Out:
#              name age            designation
# 0     kunal_gupta  36             [CEO, CTO]
# 1  Khushboo_gupta  35                HR Head
# 2    vishal_gupta  26  Head of Various Depts
# 3  Paritosh_kumar  35                    COO

# %%
import requests

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
data = requests.get(url)

# %%
type(data)
# Out:
# requests.models.Response

# %%
data.status_code
# Out:
# 200

# %%
data.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38146',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38146/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38146/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38146/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38146',
#   'id': 752837294,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI5MDU2MDAx',
#   'number': 38146,
#   'title': 'ENH: add "schema" kwarg to io.sql.get_schema method',
#   'user': {'login': 'arw2019',
#    'id': 48889395,
#    'node_id': 'MDQ6VXNlcjQ4ODg5Mzk1',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/48889395?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arw2019',
#    'html_url': 'https://github.com/arw2019',
#    'followers_url': 'https://api.github.com/users/arw2019/followers',
#    'following_url': 'https://api.github.com/users/arw2019/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/arw2019/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/arw2019/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/arw2019/subscriptions',
#    'organizations_url': 'https://api.github.com/users/arw2019/orgs',
#    'repos_url': 'https://api.github.com/users/arw2019/repos',
#    'events_url': 'https://api.github.com/users/arw2019/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/arw2019/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-29T04:41:13Z',
#   'updated_at': '2020-11-29T04:52:53Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38146',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38146',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38146.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38146.patch'},
#   'body': '- [x] closes  #28486\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry\r\n\r\nPicking up #33278',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38145',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38145/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38145/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38145/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38145',
#   'id': 752836104,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI5MDU1MTc2',
#   'number': 38145,
#   'title': 'BUG: combine_first does not retain dtypes with Timestamp DataFrames',
#   'user': {'login': 'arw2019',
#    'id': 48889395,
#    'node_id': 'MDQ6VXNlcjQ4ODg5Mzk1',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/48889395?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arw2019',
#    'html_url': 'https://github.com/arw2019',
#    'followers_url': 'https://api.github.com/users/arw2019/followers',
#    'following_url': 'https://api.github.com/users/arw2019/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/arw2019/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/arw2019/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/arw2019/subscriptions',
#    'organizations_url': 'https://api.github.com/users/arw2019/orgs',
#    'repos_url': 'https://api.github.com/users/arw2019/repos',
#    'events_url': 'https://api.github.com/users/arw2019/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/arw2019/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2020-11-29T04:31:12Z',
#   'updated_at': '2020-11-29T05:31:44Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38145',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38145',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38145.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38145.patch'},
#   'body': '- [x] closes #28481\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry\r\n\r\nPicking up #35514',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38144',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38144/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38144/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38144/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38144',
#   'id': 752824428,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI5MDQ3NTAz',
#   'number': 38144,
#   'title': 'CLN: remove unnecesary cast.maybe_convert_objects',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-29T02:57:19Z',
#   'updated_at': '2020-11-29T02:57:19Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38144',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38144',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38144.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38144.patch'},
#   'body': '',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38143',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38143/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38143/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38143/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38143',
#   'id': 752808153,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI5MDM0NTA0',
#   'number': 38143,
#   'title': 'REF: refactor out EA dispatch for _cython_operation',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-29T01:41:20Z',
#   'updated_at': '2020-11-29T02:14:50Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38143',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38143',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38143.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38143.patch'},
#   'body': 'Make our dispatching/casting explicit and self-contained.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38142',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38142/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38142/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38142/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38142',
#   'id': 752792591,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI5MDI0Mjk0',
#   'number': 38142,
#   'title': 'DEPR: ExtensionOpsMixin -> OpsMixin',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-28T23:44:03Z',
#   'updated_at': '2020-11-29T02:32:29Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38142',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38142',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38142.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38142.patch'},
#   'body': '- [x] closes #37080\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38141',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38141/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38141/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38141/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38141',
#   'id': 752770745,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI5MDEwOTk2',
#   'number': 38141,
#   'title': 'BUG: do not stringify file-like objects',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-28T21:23:29Z',
#   'updated_at': '2020-11-28T21:23:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38141',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38141',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38141.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38141.patch'},
#   'body': '- [x] closes #38125\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry\r\n\r\nI will finish this PR (fix the mypy issues) after #38018 is merged.\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38140',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38140/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38140/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38140/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38140',
#   'id': 752756750,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI5MDAyMTcz',
#   'number': 38140,
#   'title': 'BUG: Categorical.unique should keep dtype unchanged',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 35818298,
#     'node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#     'name': 'API Design',
#     'color': 'AD7FA8',
#     'default': False,
#     'description': None},
#    {'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 78527356,
#     'node_id': 'MDU6TGFiZWw3ODUyNzM1Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Categorical',
#     'name': 'Categorical',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Categorical Data Type'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-28T19:59:54Z',
#   'updated_at': '2020-11-29T00:53:23Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38140',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38140',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38140.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38140.patch'},
#   'body': '- [x] closes #18291\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry\r\n\r\nWe want to keep the same dtype as in the original after applying `unique`. For example:\r\n\r\n```python\r\n>>> dtype = pd.categoricalDtype([\'very good\', \'good\', \'neutral\', \'bad\', \'very bad\'], ordered=True)\r\n>>> cat = pd.Categorical([\'good\',\'good\', \'bad\', \'bad\'], dtype=dtype)\r\n>>> cat\r\n[good, good, bad, bad]\r\nCategories (5, object): [very good < good < neutral < bad < very bad]\r\n>>> cat.unique().dtype == cat.dtype\r\nFalse  # master\r\nTrue  # this PR\r\n```\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38139',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38139/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38139/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38139/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/38139',
#   'id': 752754697,
#   'node_id': 'MDU6SXNzdWU3NTI3NTQ2OTc=',
#   'number': 38139,
#   'title': 'TST: Add tests for observance rules in holiday.py',
#   'user': {'login': 'leonarduschen',
#    'id': 65842583,
#    'node_id': 'MDQ6VXNlcjY1ODQyNTgz',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/65842583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leonarduschen',
#    'html_url': 'https://github.com/leonarduschen',
#    'followers_url': 'https://api.github.com/users/leonarduschen/followers',
#    'following_url': 'https://api.github.com/users/leonarduschen/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/leonarduschen/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/leonarduschen/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/leonarduschen/subscriptions',
#    'organizations_url': 'https://api.github.com/users/leonarduschen/orgs',
#    'repos_url': 'https://api.github.com/users/leonarduschen/repos',
#    'events_url': 'https://api.github.com/users/leonarduschen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/leonarduschen/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-28T19:49:27Z',
#   'updated_at': '2020-11-28T19:49:34Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [x] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\nNone of the observance rules (e.g. `next_workday`, `before_nearest_workday`) are tested',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38138',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38138/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38138/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38138/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/38138',
#   'id': 752754672,
#   'node_id': 'MDU6SXNzdWU3NTI3NTQ2NzI=',
#   'number': 38138,
#   'title': 'CLN: C408 Unnecessary dict call - rewrite as a literal',
#   'user': {'login': 'fangchenli',
#    'id': 7614606,
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/7614606?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fangchenli',
#    'html_url': 'https://github.com/fangchenli',
#    'followers_url': 'https://api.github.com/users/fangchenli/followers',
#    'following_url': 'https://api.github.com/users/fangchenli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fangchenli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fangchenli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fangchenli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fangchenli/orgs',
#    'repos_url': 'https://api.github.com/users/fangchenli/repos',
#    'events_url': 'https://api.github.com/users/fangchenli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fangchenli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 106935113,
#     'node_id': 'MDU6TGFiZWwxMDY5MzUxMTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Style',
#     'name': 'Style',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Code style, linting, code_checks'},
#    {'id': 717120670,
#     'node_id': 'MDU6TGFiZWw3MTcxMjA2NzA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/good%20first%20issue',
#     'name': 'good first issue',
#     'color': '0e8a16',
#     'default': True,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-28T19:49:18Z',
#   'updated_at': '2020-11-28T19:49:45Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'The following files contain flake8 C408 Unnecessary dict call - rewrite as a literal. Good for first time contributors. See #38078 and #38116 for how to fix them. \r\n\r\n### C408\r\n- [ ] ./pandas/core/generic.py\r\n- [ ] ./pandas/core/series.py\r\n- [ ] ./pandas/core/frame.py\r\n- [ ] ./pandas/core/strings/accessor.py\r\n- [ ] ./pandas/core/dtypes/dtypes.py\r\n- [ ] ./pandas/core/computation/pytables.py\r\n- [ ] ./pandas/core/computation/expressions.py\r\n- [ ] ./pandas/core/arrays/floating.py\r\n- [ ] ./pandas/core/arrays/interval.py\r\n- [ ] ./pandas/core/arrays/numpy_.py\r\n- [ ] ./pandas/core/arrays/base.py\r\n- [ ] ./pandas/core/ops/methods.py\r\n- [ ] ./pandas/core/indexes/interval.py\r\n- [ ] ./pandas/core/indexes/multi.py\r\n- [ ] ./pandas/core/indexes/numeric.py\r\n- [ ] ./pandas/core/indexes/base.py\r\n- [ ] ./pandas/io/pytables.py\r\n- [ ] ./pandas/tests/reshape/concat/test_datetimes.py\r\n- [ ] ./pandas/tests/reshape/merge/test_merge.py\r\n- [ ] ./pandas/tests/reshape/merge/test_multi.py\r\n- [ ] ./pandas/tests/tools/test_to_numeric.py\r\n- [ ] ./pandas/tests/resample/test_time_grouper.py\r\n- [ ] ./pandas/tests/util/test_assert_series_equal.py\r\n- [ ] ./pandas/tests/util/test_assert_interval_array_equal.py\r\n- [ ] ./pandas/tests/util/test_assert_index_equal.py\r\n- [ ] ./pandas/tests/util/test_assert_extension_array_equal.py\r\n- [ ] ./pandas/tests/io/test_parquet.py\r\n- [ ] ./pandas/tests/io/generate_legacy_storage_files.py\r\n- [ ] ./pandas/tests/io/formats/test_format.py\r\n- [ ] ./pandas/tests/io/parser/test_comment.py\r\n- [ ] ./pandas/tests/io/parser/test_parse_dates.py\r\n- [ ] ./pandas/tests/io/parser/test_c_parser_only.py\r\n- [ ] ./pandas/tests/io/parser/test_dialect.py\r\n- [ ] ./pandas/tests/io/parser/test_skiprows.py\r\n- [ ] ./pandas/tests/io/parser/test_encoding.py\r\n- [ ] ./pandas/tests/io/parser/test_read_fwf.py\r\n- [ ] ./pandas/tests/io/parser/test_python_parser_only.py\r\n- [ ] ./pandas/tests/io/parser/test_na_values.py\r\n- [ ] ./pandas/tests/io/parser/test_usecols.py\r\n- [ ] ./pandas/tests/io/parser/test_quoting.py\r\n- [ ] ./pandas/tests/io/parser/test_header.py\r\n- [ ] ./pandas/tests/io/parser/test_index_col.py\r\n- [ ] ./pandas/tests/io/json/test_ujson.py\r\n- [ ] ./pandas/tests/io/json/test_normalize.py\r\n- [ ] ./pandas/tests/io/pytables/test_timezones.py\r\n- [ ] ./pandas/tests/io/pytables/test_store.py\r\n- [ ] ./pandas/tests/frame/test_reductions.py\r\n- [ ] ./pandas/tests/frame/test_arithmetic.py\r\n- [ ] ./pandas/tests/frame/methods/test_to_records.py\r\n- [ ] ./pandas/tests/frame/methods/test_sort_values.py\r\n- [ ] ./pandas/tests/frame/methods/test_fillna.py\r\n- [ ] ./pandas/tests/frame/methods/test_to_csv.py\r\n- [ ] ./pandas/tests/frame/indexing/test_indexing.py\r\n- [ ] ./pandas/tests/frame/indexing/test_where.py\r\n- [ ] ./pandas/tests/dtypes/test_inference.py\r\n- [ ] ./pandas/tests/groupby/test_function.py\r\n- [ ] ./pandas/tests/groupby/transform/test_transform.py\r\n- [ ] ./pandas/tests/plotting/test_boxplot_method.py\r\n- [ ] ./pandas/tests/plotting/frame/test_frame_subplots.py\r\n\r\n### Remove ignore setting from flake8 section\r\n- [ ] setup.cfg',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38137',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38137/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38137/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38137/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38137',
#   'id': 752753760,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI5MDAwMzg5',
#   'number': 38137,
#   'title': 'test backportability of #38120',
#   'user': {'login': 'simonjayhawkins',
#    'id': 13159005,
#    'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/13159005?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simonjayhawkins',
#    'html_url': 'https://github.com/simonjayhawkins',
#    'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#    'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#    'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#    'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#    'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1741841389,
#     'node_id': 'MDU6TGFiZWwxNzQxODQxMzg5',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20-%20Consistency',
#     'name': 'API - Consistency',
#     'color': 'b60205',
#     'default': False,
#     'description': 'Internal Consistency of API/Behavior'},
#    {'id': 53181044,
#     'node_id': 'MDU6TGFiZWw1MzE4MTA0NA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Frequency',
#     'name': 'Frequency',
#     'color': '0052cc',
#     'default': False,
#     'description': 'DateOffsets'},
#    {'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-28T19:45:13Z',
#   'updated_at': '2020-11-28T20:05:30Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38137',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38137',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38137.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38137.patch'},
#   'body': '#38120',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38136',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38136/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38136/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38136/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38136',
#   'id': 752741687,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI4OTkyNjg3',
#   'number': 38136,
#   'title': 'BUG: Categorical[dt64tz].to_numpy() losing tz',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 78527356,
#     'node_id': 'MDU6TGFiZWw3ODUyNzM1Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Categorical',
#     'name': 'Categorical',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Categorical Data Type'},
#    {'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtypes',
#     'name': 'Dtypes',
#     'color': 'e102d8',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-28T18:37:50Z',
#   'updated_at': '2020-11-28T20:41:45Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38136',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38136',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38136.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38136.patch'},
#   'body': '- [x] closes #26406\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38134',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38134/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38134/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38134/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38134',
#   'id': 752705881,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI4OTY3NDA2',
#   'number': 38134,
#   'title': 'REF: de-duplicate Block.__init__',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49094459,
#     'node_id': 'MDU6TGFiZWw0OTA5NDQ1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals',
#     'name': 'Internals',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Related to non-user accessible pandas implementation'},
#    {'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-28T16:10:13Z',
#   'updated_at': '2020-11-28T23:08:54Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38134',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38134',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38134.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38134.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] passes `black pandas`\r\n- [ ] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38131',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38131/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38131/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38131/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/38131',
#   'id': 752626841,
#   'node_id': 'MDU6SXNzdWU3NTI2MjY4NDE=',
#   'number': 38131,
#   'title': 'BUG: HDFStore mishandles pd.categorical when initialized with custom categories',
#   'user': {'login': 'PaulAmosKreiner',
#    'id': 19305531,
#    'node_id': 'MDQ6VXNlcjE5MzA1NTMx',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/19305531?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PaulAmosKreiner',
#    'html_url': 'https://github.com/PaulAmosKreiner',
#    'followers_url': 'https://api.github.com/users/PaulAmosKreiner/followers',
#    'following_url': 'https://api.github.com/users/PaulAmosKreiner/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/PaulAmosKreiner/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/PaulAmosKreiner/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/PaulAmosKreiner/subscriptions',
#    'organizations_url': 'https://api.github.com/users/PaulAmosKreiner/orgs',
#    'repos_url': 'https://api.github.com/users/PaulAmosKreiner/repos',
#    'events_url': 'https://api.github.com/users/PaulAmosKreiner/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/PaulAmosKreiner/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-28T08:35:47Z',
#   'updated_at': '2020-11-28T10:16:39Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\ndf = pd.DataFrame(columns=[\'col1\'])\r\n\r\ndf[\'col1\'] = pd.Categorical(["a","b","c","a"], categories=["c","b","a"])\r\n\r\nstore = pd.HDFStore(\'bug.h5\')\r\nstore.append(\'df\', df, data_columns=df.columns)\r\nstore.select(\'df\', "col1=\'a\'")\r\n```\r\n\r\n#### Problem description\r\n\r\nyields\r\n\r\n```\r\ncol1\r\n2\tc\r\n```\r\n\r\n#### Expected Output\r\n\r\nshould yield\r\n\r\n```\r\ncol1\r\n0\ta\r\n3\ta\r\n```\r\n\r\n#### workaround\r\n\r\nsimply don\'t provide categories to the pd.Categorical(). everything works fine with the inferred categories – at least in my project from what I have seen.\r\n\r\n#### reference & questions\r\n\r\nissue in pytables (where I don\'t think it belongs at this point): https://github.com/PyTables/PyTables/issues/714\r\n\r\nthe bug is invariant with regard to the following HDFStore settings:\r\n- choosing "fixed" or "table" format\r\n- using compression\r\n\r\nare categories even officially supported in HDFStore at this point? The IO guide still does not mention the type as supported. ([https://pandas.pydata.org/pandas-docs/dev/user_guide/io.html#storing-types](url)) Maybe create a warning if it really is not supported still.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\ndefault Google Colaboratory as of 28.11.2020\r\n\r\n```\r\ncommit           : 67a3d4241ab84419856b84fc3ebc9abcbe66c6b3\r\npython           : 3.6.9.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 4.19.112+\r\nVersion          : #1 SMP Thu Jul 23 08:00:38 PDT 2020\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.1.4\r\nnumpy            : 1.18.5\r\npytz             : 2018.9\r\ndateutil         : 2.8.1\r\npip              : 19.3.1\r\nsetuptools       : 50.3.2\r\nCython           : 0.29.21\r\npytest           : 3.6.4\r\nhypothesis       : None\r\nsphinx           : 1.8.5\r\nblosc            : None\r\nfeather          : 0.4.1\r\nxlsxwriter       : None\r\nlxml.etree       : 4.2.6\r\nhtml5lib         : 1.0.1\r\npymysql          : None\r\npsycopg2         : 2.7.6.1 (dt dec pq3 ext lo64)\r\njinja2           : 2.11.2\r\nIPython          : 5.5.0\r\npandas_datareader: 0.9.0\r\nbs4              : 4.6.3\r\nbottleneck       : 1.3.2\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.2.2\r\nnumexpr          : 2.7.1\r\nodfpy            : None\r\nopenpyxl         : 2.5.9\r\npandas_gbq       : 0.13.3\r\npyarrow          : 0.14.1\r\npytables         : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.4.1\r\nsqlalchemy       : 1.3.20\r\ntables           : 3.4.4\r\ntabulate         : 0.8.7\r\nxarray           : 0.15.1\r\nxlrd             : 1.1.0\r\nxlwt             : 1.3.0\r\nnumba            : 0.48.0\r\n```\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38130',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38130/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38130/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38130/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38130',
#   'id': 752593088,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI4ODg4NDM5',
#   'number': 38130,
#   'title': 'REF: use np.where instead of maybe_upcast_putmask in nanops',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-28T04:12:17Z',
#   'updated_at': '2020-11-28T04:12:17Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38130',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38130',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38130.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38130.patch'},
#   'body': 'This way we make at most one copy.  Also we get rid of the only use of maybe_upcast_putmask that has fill_value of anything other than np.nan, so in a follow-up it can be simplified.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38129',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38129/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38129/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38129/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38129',
#   'id': 752592236,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI4ODg3ODQ2',
#   'number': 38129,
#   'title': 'REF: de-duplicate ndarray[datetimelike] wrapping',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'},
#    {'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2020-11-28T04:05:41Z',
#   'updated_at': '2020-11-28T22:50:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38129',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38129',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38129.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38129.patch'},
#   'body': '',
#   'performed_via_github_app': None},
# ...
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'Long overdue follow-up item on the initial merge of the nullable float64/float32 support (https://github.com/pandas-dev/pandas/pull/34307).\r\n\r\nList of follow-up TODO items:\r\n\r\n* [ ] Update the `convert_dtypes` method to also return nullable floats (one question here: what with floats that are all "integer"-like? I think we want to keep returning nullable int for that, but we might want to add a parameter controlling that behaviour?)\r\n* [ ] Arithmetic operations with IntegerArray/BooleanArray can now return a FloatingArray instead of numpy float array(eg division with Int64 should give Float64\r\n* [ ] Ufuncs on IntegerArray/BooleanArray can return FloatingArray, ufuncs on mixture of IntegerArray/FloatArray\r\n* [ ] Consolidate some tests that are common for integer/boolean/float\r\n* [ ] Deduplicate more things between the Array classes and move to BaseMaskedArray (eg the arithmetic / comparison ops can probably be moved with a bit of refactoring)\r\n  * [ ] `__from_arrow__`\r\n  * [ ] ufuncs\r\n  * [ ] `coerce_to_array`, but this will probably require some refactoring\r\n* [ ] Honor the formatting options (eg precision)\r\n* [ ] Fix membership test for np.nan (`np.nan in arr`), see https://github.com/pandas-dev/pandas/pull/37867#discussion_r531079439\r\n\r\nAnd of course, we also still have the NA vs NaN discussion to further flesh out (https://github.com/pandas-dev/pandas/issues/32265), but this issue is for the direct practical TODO items.\r\n\r\n\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38109',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38109/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38109/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38109/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38109',
#   'id': 752230879,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI4NTk1MTIw',
#   'number': 38109,
#   'title': 'DOC: Add behavior for Index argument in DataFrame.loc',
#   'user': {'login': 'hongshaoyang',
#    'id': 19281800,
#    'node_id': 'MDQ6VXNlcjE5MjgxODAw',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/19281800?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hongshaoyang',
#    'html_url': 'https://github.com/hongshaoyang',
#    'followers_url': 'https://api.github.com/users/hongshaoyang/followers',
#    'following_url': 'https://api.github.com/users/hongshaoyang/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hongshaoyang/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hongshaoyang/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hongshaoyang/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hongshaoyang/orgs',
#    'repos_url': 'https://api.github.com/users/hongshaoyang/repos',
#    'events_url': 'https://api.github.com/users/hongshaoyang/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hongshaoyang/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-27T12:48:37Z',
#   'updated_at': '2020-11-28T18:31:27Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38109',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38109',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38109.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38109.patch'},
#   'body': '- [x] closes #36850\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38106',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38106/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38106/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38106/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38106',
#   'id': 751983934,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI4Mzk1NzUy',
#   'number': 38106,
#   'title': '[WIP] BUG in Series.interpolate: limit_area/limit_direction kwargs with method="pad"/"bfill" have no effect',
#   'user': {'login': 'arw2019',
#    'id': 48889395,
#    'node_id': 'MDQ6VXNlcjQ4ODg5Mzk1',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/48889395?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arw2019',
#    'html_url': 'https://github.com/arw2019',
#    'followers_url': 'https://api.github.com/users/arw2019/followers',
#    'following_url': 'https://api.github.com/users/arw2019/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/arw2019/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/arw2019/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/arw2019/subscriptions',
#    'organizations_url': 'https://api.github.com/users/arw2019/orgs',
#    'repos_url': 'https://api.github.com/users/arw2019/repos',
#    'events_url': 'https://api.github.com/users/arw2019/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/arw2019/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-11-27T05:06:06Z',
#   'updated_at': '2020-11-27T06:06:21Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38106',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38106',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38106.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38106.patch'},
#   'body': '- [x] closes #26796\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry\r\n\r\nPicking up #31048',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38105',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38105/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38105/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38105/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/38105',
#   'id': 751967653,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTI4MzgyODI2',
#   'number': 38105,
#   'title': 'REF: implement _should_compare',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2020-11-27T04:11:58Z',
#   'updated_at': '2020-11-28T21:19:14Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/38105',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/38105',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/38105.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/38105.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n\r\nIndex._is_comparable_dtype is limited because it misses a few cases: object dtype, and sub-dtypes within categorical.  This implements Indes._should_compare, which handles those correctly.  It then implements `_get_indexer_non_comparable` for cases in which we short-circuit non-comparable dtypes.\r\n\r\nAs a proof of concept, this then uses _should_compare and _get_indexer_non_comparable for `PeriodIndex.get_indexer`.\r\n\r\nThe behavior change, which this tests, is one that IIUC is a bug.  That is, when we do get_indexer with a method and non-comparable dtypes, we should raise instead of return all minus-ones.\r\n\r\nIf implemented, we\'ll be able to use _should_compare to simplify all of the get_indexer, get_indexer_non_unique, and set op methods.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38104',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38104/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38104/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/38104/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/38104',
#   'id': 751952541,
#   'node_id': 'MDU6SXNzdWU3NTE5NTI1NDE=',
#   'number': 38104,
#   'title': 'BUG: RangeIndex is not being appened correctly',
#   'user': {'login': 'galipremsagar',
#    'id': 11664259,
#    'node_id': 'MDQ6VXNlcjExNjY0MjU5',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/11664259?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/galipremsagar',
#    'html_url': 'https://github.com/galipremsagar',
#    'followers_url': 'https://api.github.com/users/galipremsagar/followers',
#    'following_url': 'https://api.github.com/users/galipremsagar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/galipremsagar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/galipremsagar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/galipremsagar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/galipremsagar/orgs',
#    'repos_url': 'https://api.github.com/users/galipremsagar/repos',
#    'events_url': 'https://api.github.com/users/galipremsagar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/galipremsagar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 685114413,
#     'node_id': 'MDU6TGFiZWw2ODUxMTQ0MTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Parquet',
#     'name': 'IO Parquet',
#     'color': '5319e7',
#     'default': False,
#     'description': 'parquet, feather, pyarrow'},
#    {'id': 2533668378,
#     'node_id': 'MDU6TGFiZWwyNTMzNjY4Mzc4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Upstream%20issue',
#     'name': 'Upstream issue',
#     'color': 'd8439a',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2020-11-27T03:19:05Z',
#   'updated_at': '2020-11-27T08:23:50Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\n>>> import pandas as pd\r\n>>> df1 = pd.DataFrame({'a':[1, 2, 3]})\r\n>>> df1.to_parquet('abc/one.parquet')\r\n>>> df2 = pd.DataFrame({'a':[4, 5, 6]})\r\n>>> df2.to_parquet('abc/two.parquet')\r\n>>> df3 = pd.DataFrame({'a':[7, 8, 9]})\r\n>>> df3.to_parquet('abc/three.parquet')\r\n>>> pd.read_parquet('abc/')\r\n   a\r\n0  1\r\n1  2\r\n2  3\r\n3  7\r\n4  8\r\n5  9\r\n6  4\r\n7  5\r\n8  6\r\n\r\n```\r\n\r\n#### Problem description\r\n\r\nWhen there are multiple parquet files with identical/non-identical  RangeIndex objects I think doing `pd.read_parquet` should ideally be appending all the RangeIndex objects of each parquet file.\r\n\r\n#### Expected Output\r\n\r\n```python\r\n>>> pd.read_parquet('abc/')\r\n   a\r\n0  1\r\n1  2\r\n2  3\r\n0  7\r\n1  8\r\n2  9\r\n0  4\r\n1  5\r\n2  6\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 67a3d4241ab84419856b84fc3ebc9abcbe66c6b3\r\npython           : 3.7.3.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.1.0\r\nVersion          : Darwin Kernel Version 20.1.0: Sat Oct 31 00:07:11 PDT 2020; root:xnu-7195.50.7~2/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : en_US.UTF-8\r\npandas           : 1.1.4\r\nnumpy            : 1.19.2\r\npytz             : 2020.1\r\ndateutil         : 2.8.1\r\npip              : 20.2.3\r\nsetuptools       : 50.3.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : 5.29.0\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 1.0.1\r\npytables         : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n",
#   'performed_via_github_app': None}]

# %%
# type casting in data

# %%
df5 = pd.read_html('C:/Users/VGupta/OneDrive - Sonicwall Inc/examples/fdic_failed_bank_list.html')
df5
# Out:
# [                             Bank Name             City  ST   CERT  \
#  0                          Allied Bank         Mulberry  AR     91
#  1         The Woodbury Banking Company         Woodbury  GA  11297
#  2               First CornerStone Bank  King of Prussia  PA  35312
#  3                   Trust Company Bank          Memphis  TN   9956
#  4           North Milwaukee State Bank        Milwaukee  WI  20364
#  ..                                 ...              ...  ..    ...
#  542                 Superior Bank, FSB         Hinsdale  IL  32646
#  543                Malta National Bank            Malta  OH   6629
#  544    First Alliance Bank & Trust Co.       Manchester  NH  34264
#  545  National State Bank of Metropolis       Metropolis  IL   3815
#  546                   Bank of Honolulu         Honolulu  HI  21029
#
#                     Acquiring Institution        Closing Date  \
#  0                           Today's Bank  September 23, 2016
#  1                            United Bank     August 19, 2016
#  2    First-Citizens Bank & Trust Company         May 6, 2016
#  3             The Bank of Fayette County      April 29, 2016
#  4    First-Citizens Bank & Trust Company      March 11, 2016
#  ..                                   ...                 ...
#  542                Superior Federal, FSB       July 27, 2001
#  543                    North Valley Bank         May 3, 2001
#  544  Southern New Hampshire Bank & Trust    February 2, 2001
#  545              Banterra Bank of Marion   December 14, 2000
#  546                   Bank of the Orient    October 13, 2000
#
#            Updated Date
#  0    November 17, 2016
#  1    November 17, 2016
#  2    September 6, 2016
#  3    September 6, 2016
#  4        June 16, 2016
#  ..                 ...
#  542    August 19, 2014
#  543  November 18, 2002
#  544  February 18, 2003
#  545     March 17, 2005
#  546     March 17, 2005
#
#  [547 rows x 7 columns]]

# %%
type(df5)
# Out:
# list

# %%
df6 = df5[0]
df6
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# 1                            United Bank     August 19, 2016
# 2    First-Citizens Bank & Trust Company         May 6, 2016
# 3             The Bank of Fayette County      April 29, 2016
# 4    First-Citizens Bank & Trust Company      March 11, 2016
# ..                                   ...                 ...
# 542                Superior Federal, FSB       July 27, 2001
# 543                    North Valley Bank         May 3, 2001
# 544  Southern New Hampshire Bank & Trust    February 2, 2001
# 545              Banterra Bank of Marion   December 14, 2000
# 546                   Bank of the Orient    October 13, 2000
#
#           Updated Date
# 0    November 17, 2016
# 1    November 17, 2016
# 2    September 6, 2016
# 3    September 6, 2016
# 4        June 16, 2016
# ..                 ...
# 542    August 19, 2014
# 543  November 18, 2002
# 544  February 18, 2003
# 545     March 17, 2005
# 546     March 17, 2005
#
# [547 rows x 7 columns]

# %%
print(type(df6))
print(type(df6['Closing Date'][0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>

# %%
pd.to_datetime(df6['Closing Date'])
# Out:
# 0     2016-09-23
# 1     2016-08-19
# 2     2016-05-06
# 3     2016-04-29
# 4     2016-03-11
#          ...
# 542   2001-07-27
# 543   2001-05-03
# 544   2001-02-02
# 545   2000-12-14
# 546   2000-10-13
# Name: Closing Date, Length: 547, dtype: datetime64[ns]

# %%
closing_timestamp = pd.to_datetime(df6['Closing Date'])
closing_timestamp
# Out:
# 0     2016-09-23
# 1     2016-08-19
# 2     2016-05-06
# 3     2016-04-29
# 4     2016-03-11
#          ...
# 542   2001-07-27
# 543   2001-05-03
# 544   2001-02-02
# 545   2000-12-14
# 546   2000-10-13
# Name: Closing Date, Length: 547, dtype: datetime64[ns]

# %%
closing_timestamp.count()
# Out:
# 547

# %%
closing_timestamp.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: Closing Date, dtype: int64

# %%
#Binary data formats
df6.to_pickle('pickel_format_data')

# %%
df7 = pd.read_pickle('pickel_format_data')
df7
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# 1                            United Bank     August 19, 2016
# 2    First-Citizens Bank & Trust Company         May 6, 2016
# 3             The Bank of Fayette County      April 29, 2016
# 4    First-Citizens Bank & Trust Company      March 11, 2016
# ..                                   ...                 ...
# 542                Superior Federal, FSB       July 27, 2001
# 543                    North Valley Bank         May 3, 2001
# 544  Southern New Hampshire Bank & Trust    February 2, 2001
# 545              Banterra Bank of Marion   December 14, 2000
# 546                   Bank of the Orient    October 13, 2000
#
#           Updated Date
# 0    November 17, 2016
# 1    November 17, 2016
# 2    September 6, 2016
# 3    September 6, 2016
# 4        June 16, 2016
# ..                 ...
# 542    August 19, 2014
# 543  November 18, 2002
# 544  February 18, 2003
# 545     March 17, 2005
# 546     March 17, 2005
#
# [547 rows x 7 columns]

# %%
import numpy as np

# %%
df8 = pd.DataFrame({'a': np.random.randn(100)})
df8
# Out:
#            a
# 0   0.900163
# 1  -0.076961
# 2  -0.537764
# 3  -0.293654
# 4  -0.369819
# ..       ...
# 95 -0.961709
# 96 -0.021061
# 97 -0.204708
# 98 -1.722506
# 99  0.763631
#
# [100 rows x 1 columns]

# %%
store = pd.HDFStore('mydata.h5')
store
store['obj1'] = df8
store['obj1_col'] = df8['a']
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store['obj1']
# Out:
#            a
# 0   0.900163
# 1  -0.076961
# 2  -0.537764
# 3  -0.293654
# 4  -0.369819
# ..       ...
# 95 -0.961709
# 96 -0.021061
# 97 -0.204708
# 98 -1.722506
# 99  0.763631
#
# [100 rows x 1 columns]
